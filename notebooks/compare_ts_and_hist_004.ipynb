# %%
import os

import utils

# %%
# %%time

casename = "g.e22.G1850ECO_JRA_HR.TL319_t13.004"

# Directories to search for netCDF files
caseroot = os.path.join(os.sep, "glade", "work", "mlevy", "hi-res_BGC_JRA", "cases")
campaign_root = os.path.join(os.sep, "glade", "campaign", "cesm", "development", "bgcwg", "projects", "hi-res_JRA", "cases")
output_roots = [os.path.join(campaign_root, casename, "output")]
output_roots += utils.gen_output_roots_from_caseroot(os.path.join(caseroot, casename))

utils.timeseries_and_history_comparison(casename, output_roots)
# Out:
# Checking year 0001...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0001 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0001
# ----
# Checking year 0002...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0002 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0002
# ----
# Checking year 0003...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0003 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0003
# ----
# Checking year 0004...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0004 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0004
# ----
# Checking year 0005...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0005 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0005
# ----
# Checking year 0006...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0006 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0006
# ----
# Checking year 0007...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0007 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0007
# ----
# Checking year 0008...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0008 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0008
# ----
# Checking year 0009...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0009 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0009
# ----
# Checking year 0010...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0010 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0010
# ----
# Checking year 0011...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0011 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0011
# ----
# Checking year 0012...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0012 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0012
# ----
# Checking year 0013...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0013 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0013
# ----
# Checking year 0014...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0014 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0014
# ----
# Checking year 0015...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0015 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0015
# ----
# Checking year 0016...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0016 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0016
# ----
# Checking year 0017...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0017 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0017
# ----
# Checking year 0018...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0018 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0018
# ----
# Checking year 0019...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0019 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0019
# ----
# Checking year 0020...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0020 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0020
# ----
# Checking year 0021...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0021 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0021
# ----
# Checking year 0022...
# ... checking stream pop.h.nyear1 ...
# Skipping year 0022 because there are no history files in stream pop.h.nyear1
# Could not find time series for all variables in year 0022
# ----
# Checking year 0023...
# ... checking stream pop.h.nyear1 ...
# ... checking stream pop.h.nday1 ...
# ... checking stream pop.h ...
# ... checking stream cice.h1 ...
# ... checking stream cice.h ...
# All variables available in time series for year 0023
# ----
# Checking year 0024...
# ... checking stream pop.h.nyear1 ...
# ... checking stream pop.h.nday1 ...
# ... checking stream pop.h ...
# ... checking stream cice.h1 ...
# ... checking stream cice.h ...
# All variables available in time series for year 0024
# ----
# Checking year 0025...
# ... checking stream pop.h.nyear1 ...
# ... checking stream pop.h.nday1 ...
# ... checking stream pop.h ...
# ... checking stream cice.h1 ...
# ... checking stream cice.h ...
# All variables available in time series for year 0025
# ----
# Checking year 0026...
# ... checking stream pop.h.nyear1 ...
# ... checking stream pop.h.nday1 ...
# ... checking stream pop.h ...
# ... checking stream cice.h1 ...
# ... checking stream cice.h ...
# All variables available in time series for year 0026
# ----
# Checking year 0027...
# ... checking stream pop.h.nyear1 ...
# Could not find time series for year 0027
# CPU times: user 57.8 s, sys: 6.43 s, total: 1min 4s
# Wall time: 2min 21s
